# %% [markdown]
# KNN Algorithm
# Initial Implementation in separate blocks

# %%
import pandas as pd
import numpy as np

from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score 
from sklearn.metrics import precision_score 
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import KFold, RandomizedSearchCV, GridSearchCV
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

dataset = pd.read_csv("../data/Cancer_Data.csv")

if 'Unnamed: 32' in dataset.columns:
    dataset.drop('Unnamed: 32', axis=1, inplace=True)
dataset['diagnosis'].replace(['B', 'M'],[0, 1], inplace=True) # B = 0, M = 1

# %%
#x = dataset.drop(['diagnosis','id'],axis=1)
x = dataset.iloc[:, 2:12]
y = dataset['diagnosis']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean
# 0          17.99         10.38          122.80     1001.0          0.11840  \
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean
# 0             0.27760         0.30010              0.14710         0.2419  \
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      fractal_dimension_mean
# 0                   0.07871
# 1                   0.05667
# 2                   0.05999
# 3                   0.09744
# 4                   0.05883
# ..                      ...
# 564                 0.05623
# 565                 0.05533
# 566                 0.05648
# 567                 0.07016
# 568                 0.05884
#
# [569 rows x 10 columns]

# %%
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train)
x_test = sc_x.transform(x_test)

# %%
k = sqrt(len(y_test)) #this is 13 but putting the variable gives errors

classifier = KNeighborsClassifier(n_neighbors=13, p=2, metric='euclidean')

# %%
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=13)

# %%
y_pred = classifier.predict(x_test)

# %%
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred))
print(recall_score(y_test, y_pred))
print(f1_score(y_test, y_pred))
# Out:
# 0.9370629370629371
# 0.92
# 0.9019607843137255
# 0.9108910891089109

# %% [markdown]
# Which attributes are better?
# All, Mean, SE or Worst?

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import recall_score


def run_predictions(p1, p2):
    recall_score_list = []
    for i in range(0, 100):  
        dataset = pd.read_csv("../data/Cancer_Data.csv")

        if 'Unnamed: 32' in dataset.columns:
            dataset.drop('Unnamed: 32', axis=1, inplace=True)
        dataset['diagnosis'].replace(['B', 'M'],[0, 1], inplace=True) # B = 0, M = 1 

        x = dataset.iloc[:, p1:p2]
        y = dataset['diagnosis']

        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

        sc_x = StandardScaler()
        x_train = sc_x.fit_transform(x_train)
        x_test = sc_x.transform(x_test)

        #default k = 5
        #default metric = minkowski
        #default weights = uniform
        #defualt algorithm = auto
        classifier = KNeighborsClassifier(n_neighbors=5, metric='minkowski', weights='uniform', algorithm='auto')

        classifier.fit(x_train, y_train)

        y_pred = classifier.predict(x_test)

        recall_score_list.append(recall_score(y_test, y_pred))

    print("Avg Recall Score:   ", round(100 * (sum(recall_score_list) / len(recall_score_list)), 2), "%")

print("KNN with default values is running 100 times for each of these cases")
print("============================================")
print("Using all attributes")
run_predictions(2, 32)
print("============================================")
print("Using mean attributes")
run_predictions(2, 12)
print("============================================")
print("Using standard error attributes")
run_predictions(12, 22)
print("============================================")
print("Using worst attributes")
run_predictions(22, 32)
print("============================================")

#from sklearn.model_selection import GridSearchCV

#grid_params = { 'n_neighbors' : [5,7,9,11,13,15],
#               'weights' : ['uniform','distance'],
#               'metric' : ['minkowski','euclidean','manhattan']}
# Out:
# KNN with default values is running 100 times for each of these cases
# ============================================
# Using all attributes
# Avg Recall Score:    91.78 %
# ============================================
# Using mean attributes
# Avg Recall Score:    92.28 %
# ============================================
# Using standard error attributes
# Avg Recall Score:    75.72 %
# ============================================
# Using worst attributes
# Avg Recall Score:    94.03 %
# ============================================

# %% [markdown]
# We conclude the ideal attributes to base our research on are the worst attributes, since they give us the highest average recall score, using k-nn with the default hyperparameters.

# %% [markdown]
# What are the best hyperparameters to use?
# - k number of neighbours: small odd number
# - m metric: minkowski, euclidean or manhattan
# - w weights: uniform or distance

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score 
from sklearn.metrics import precision_score 
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score

recall_score_list = []
print("Avg Recall Score:")
for k in [1, 3, 5, 7, 9, 11, 13, 15, 17]:
    for m in ['minkowski','euclidean','manhattan']:
        for w in ['uniform','distance']:
            for a in ['auto', 'ball_tree', 'kd_tree', 'brute']:
                for i in range(1, 100):  
                    dataset = pd.read_csv("../data/Cancer_Data.csv")

                    if 'Unnamed: 32' in dataset.columns:
                        dataset.drop('Unnamed: 32', axis=1, inplace=True)
                    dataset['diagnosis'].replace(['B', 'M'],[0, 1], inplace=True) # B = 0, M = 1 

                    x = dataset.iloc[:, 22:32]
                    y = dataset['diagnosis']

                    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

                    sc_x = StandardScaler()
                    x_train = sc_x.fit_transform(x_train)
                    x_test = sc_x.transform(x_test)

                    classifier = KNeighborsClassifier(n_neighbors=k, metric=m, weights=w, algorithm=a)

                    classifier.fit(x_train, y_train)

                    y_pred = classifier.predict(x_test)

                    recall_score_list.append(recall_score(y_test, y_pred))
                    
                print("k =",k,"| m =", m,"| w =",w,"| a =",a, ":", round(100 * (sum(recall_score_list) / len(recall_score_list)), 2), "%")
# Out:
# Avg Recall Score:
# k = 1 | m = minkowski | w = uniform | a = auto : 94.11 %
# k = 1 | m = minkowski | w = uniform | a = ball_tree : 94.48 %
# k = 1 | m = minkowski | w = uniform | a = kd_tree : 94.25 %
# k = 1 | m = minkowski | w = uniform | a = brute : 94.01 %
# k = 1 | m = minkowski | w = distance | a = auto : 94.15 %
# k = 1 | m = minkowski | w = distance | a = ball_tree : 94.12 %
# k = 1 | m = minkowski | w = distance | a = kd_tree : 94.14 %
# k = 1 | m = minkowski | w = distance | a = brute : 94.03 %
# k = 1 | m = euclidean | w = uniform | a = auto : 94.04 %
# k = 1 | m = euclidean | w = uniform | a = ball_tree : 94.07 %
# k = 1 | m = euclidean | w = uniform | a = kd_tree : 94.08 %
# k = 1 | m = euclidean | w = uniform | a = brute : 94.13 %
# k = 1 | m = euclidean | w = distance | a = auto : 94.09 %
# k = 1 | m = euclidean | w = distance | a = ball_tree : 94.08 %
# k = 1 | m = euclidean | w = distance | a = kd_tree : 94.11 %
# k = 1 | m = euclidean | w = distance | a = brute : 94.06 %
# k = 1 | m = manhattan | w = uniform | a = auto : 93.99 %
# k = 1 | m = manhattan | w = uniform | a = ball_tree : 93.93 %
# k = 1 | m = manhattan | w = uniform | a = kd_tree : 93.86 %
# k = 1 | m = manhattan | w = uniform | a = brute : 93.8 %
# k = 1 | m = manhattan | w = distance | a = auto : 93.75 %
# k = 1 | m = manhattan | w = distance | a = ball_tree : 93.69 %
# k = 1 | m = manhattan | w = distance | a = kd_tree : 93.65 %
# k = 1 | m = manhattan | w = distance | a = brute : 93.62 %
# k = 3 | m = minkowski | w = uniform | a = auto : 93.6 %
# k = 3 | m = minkowski | w = uniform | a = ball_tree : 93.58 %
# k = 3 | m = minkowski | w = uniform | a = kd_tree : 93.59 %
# k = 3 | m = minkowski | w = uniform | a = brute : 93.55 %
# k = 3 | m = minkowski | w = distance | a = auto : 93.53 %
# k = 3 | m = minkowski | w = distance | a = ball_tree : 93.51 %
# k = 3 | m = minkowski | w = distance | a = kd_tree : 93.49 %
# k = 3 | m = minkowski | w = distance | a = brute : 93.47 %
# k = 3 | m = euclidean | w = uniform | a = auto : 93.44 %
# k = 3 | m = euclidean | w = uniform | a = ball_tree : 93.43 %
# k = 3 | m = euclidean | w = uniform | a = kd_tree : 93.41 %
# k = 3 | m = euclidean | w = uniform | a = brute : 93.4 %
# k = 3 | m = euclidean | w = distance | a = auto : 93.39 %
# k = 3 | m = euclidean | w = distance | a = ball_tree : 93.39 %
# k = 3 | m = euclidean | w = distance | a = kd_tree : 93.38 %
# k = 3 | m = euclidean | w = distance | a = brute : 93.38 %
# k = 3 | m = manhattan | w = uniform | a = auto : 93.4 %
# k = 3 | m = manhattan | w = uniform | a = ball_tree : 93.44 %
# k = 3 | m = manhattan | w = uniform | a = kd_tree : 93.47 %
# k = 3 | m = manhattan | w = uniform | a = brute : 93.51 %
# k = 3 | m = manhattan | w = distance | a = auto : 93.52 %
# k = 3 | m = manhattan | w = distance | a = ball_tree : 93.56 %
# k = 3 | m = manhattan | w = distance | a = kd_tree : 93.58 %
# k = 3 | m = manhattan | w = distance | a = brute : 93.6 %
# k = 5 | m = minkowski | w = uniform | a = auto : 93.59 %
# k = 5 | m = minkowski | w = uniform | a = ball_tree : 93.58 %
# k = 5 | m = minkowski | w = uniform | a = kd_tree : 93.58 %
# k = 5 | m = minkowski | w = uniform | a = brute : 93.57 %
# k = 5 | m = minkowski | w = distance | a = auto : 93.56 %
# k = 5 | m = minkowski | w = distance | a = ball_tree : 93.55 %
# k = 5 | m = minkowski | w = distance | a = kd_tree : 93.54 %
# k = 5 | m = minkowski | w = distance | a = brute : 93.53 %
# k = 5 | m = euclidean | w = uniform | a = auto : 93.51 %
# k = 5 | m = euclidean | w = uniform | a = ball_tree : 93.5 %
# k = 5 | m = euclidean | w = uniform | a = kd_tree : 93.5 %
# k = 5 | m = euclidean | w = uniform | a = brute : 93.5 %
# k = 5 | m = euclidean | w = distance | a = auto : 93.5 %
# k = 5 | m = euclidean | w = distance | a = ball_tree : 93.5 %
# k = 5 | m = euclidean | w = distance | a = kd_tree : 93.49 %
# k = 5 | m = euclidean | w = distance | a = brute : 93.48 %
# k = 5 | m = manhattan | w = uniform | a = auto : 93.49 %
# k = 5 | m = manhattan | w = uniform | a = ball_tree : 93.5 %
# k = 5 | m = manhattan | w = uniform | a = kd_tree : 93.52 %
# k = 5 | m = manhattan | w = uniform | a = brute : 93.54 %
# k = 5 | m = manhattan | w = distance | a = auto : 93.55 %
# k = 5 | m = manhattan | w = distance | a = ball_tree : 93.57 %
# k = 5 | m = manhattan | w = distance | a = kd_tree : 93.58 %
# k = 5 | m = manhattan | w = distance | a = brute : 93.59 %
# k = 7 | m = minkowski | w = uniform | a = auto : 93.57 %
# k = 7 | m = minkowski | w = uniform | a = ball_tree : 93.55 %
# k = 7 | m = minkowski | w = uniform | a = kd_tree : 93.54 %
# k = 7 | m = minkowski | w = uniform | a = brute : 93.52 %
# k = 7 | m = minkowski | w = distance | a = auto : 93.5 %
# k = 7 | m = minkowski | w = distance | a = ball_tree : 93.49 %
# k = 7 | m = minkowski | w = distance | a = kd_tree : 93.48 %
# k = 7 | m = minkowski | w = distance | a = brute : 93.48 %
# k = 7 | m = euclidean | w = uniform | a = auto : 93.46 %
# k = 7 | m = euclidean | w = uniform | a = ball_tree : 93.45 %
# k = 7 | m = euclidean | w = uniform | a = kd_tree : 93.44 %
# k = 7 | m = euclidean | w = uniform | a = brute : 93.43 %
# k = 7 | m = euclidean | w = distance | a = auto : 93.42 %
# k = 7 | m = euclidean | w = distance | a = ball_tree : 93.42 %
# k = 7 | m = euclidean | w = distance | a = kd_tree : 93.41 %
# k = 7 | m = euclidean | w = distance | a = brute : 93.4 %
# k = 7 | m = manhattan | w = uniform | a = auto : 93.41 %
# k = 7 | m = manhattan | w = uniform | a = ball_tree : 93.42 %
# k = 7 | m = manhattan | w = uniform | a = kd_tree : 93.44 %
# k = 7 | m = manhattan | w = uniform | a = brute : 93.45 %
# k = 7 | m = manhattan | w = distance | a = auto : 93.44 %
# k = 7 | m = manhattan | w = distance | a = ball_tree : 93.46 %
# k = 7 | m = manhattan | w = distance | a = kd_tree : 93.47 %
# k = 7 | m = manhattan | w = distance | a = brute : 93.48 %
# k = 9 | m = minkowski | w = uniform | a = auto : 93.47 %
# k = 9 | m = minkowski | w = uniform | a = ball_tree : 93.46 %
# k = 9 | m = minkowski | w = uniform | a = kd_tree : 93.45 %
# k = 9 | m = minkowski | w = uniform | a = brute : 93.46 %
# k = 9 | m = minkowski | w = distance | a = auto : 93.45 %
# k = 9 | m = minkowski | w = distance | a = ball_tree : 93.45 %
# k = 9 | m = minkowski | w = distance | a = kd_tree : 93.44 %
# k = 9 | m = minkowski | w = distance | a = brute : 93.43 %
# k = 9 | m = euclidean | w = uniform | a = auto : 93.42 %
# k = 9 | m = euclidean | w = uniform | a = ball_tree : 93.41 %
# k = 9 | m = euclidean | w = uniform | a = kd_tree : 93.41 %
# k = 9 | m = euclidean | w = uniform | a = brute : 93.4 %
# k = 9 | m = euclidean | w = distance | a = auto : 93.4 %
# k = 9 | m = euclidean | w = distance | a = ball_tree : 93.39 %
# k = 9 | m = euclidean | w = distance | a = kd_tree : 93.38 %
# k = 9 | m = euclidean | w = distance | a = brute : 93.38 %
# k = 9 | m = manhattan | w = uniform | a = auto : 93.39 %
# k = 9 | m = manhattan | w = uniform | a = ball_tree : 93.4 %
# k = 9 | m = manhattan | w = uniform | a = kd_tree : 93.4 %
# k = 9 | m = manhattan | w = uniform | a = brute : 93.4 %
# k = 9 | m = manhattan | w = distance | a = auto : 93.4 %
# k = 9 | m = manhattan | w = distance | a = ball_tree : 93.41 %
# k = 9 | m = manhattan | w = distance | a = kd_tree : 93.41 %
# k = 9 | m = manhattan | w = distance | a = brute : 93.42 %
# k = 11 | m = minkowski | w = uniform | a = auto : 93.42 %
# k = 11 | m = minkowski | w = uniform | a = ball_tree : 93.41 %
# k = 11 | m = minkowski | w = uniform | a = kd_tree : 93.4 %
# k = 11 | m = minkowski | w = uniform | a = brute : 93.39 %
# k = 11 | m = minkowski | w = distance | a = auto : 93.39 %
# k = 11 | m = minkowski | w = distance | a = ball_tree : 93.38 %
# k = 11 | m = minkowski | w = distance | a = kd_tree : 93.38 %
# k = 11 | m = minkowski | w = distance | a = brute : 93.37 %
# k = 11 | m = euclidean | w = uniform | a = auto : 93.37 %
# k = 11 | m = euclidean | w = uniform | a = ball_tree : 93.36 %
# k = 11 | m = euclidean | w = uniform | a = kd_tree : 93.35 %
# k = 11 | m = euclidean | w = uniform | a = brute : 93.35 %
# k = 11 | m = euclidean | w = distance | a = auto : 93.35 %
# k = 11 | m = euclidean | w = distance | a = ball_tree : 93.34 %
# k = 11 | m = euclidean | w = distance | a = kd_tree : 93.34 %
# k = 11 | m = euclidean | w = distance | a = brute : 93.33 %
# k = 11 | m = manhattan | w = uniform | a = auto : 93.33 %
# k = 11 | m = manhattan | w = uniform | a = ball_tree : 93.34 %
# k = 11 | m = manhattan | w = uniform | a = kd_tree : 93.34 %
# k = 11 | m = manhattan | w = uniform | a = brute : 93.34 %
# k = 11 | m = manhattan | w = distance | a = auto : 93.34 %
# k = 11 | m = manhattan | w = distance | a = ball_tree : 93.34 %
# k = 11 | m = manhattan | w = distance | a = kd_tree : 93.35 %
# k = 11 | m = manhattan | w = distance | a = brute : 93.35 %
# k = 13 | m = minkowski | w = uniform | a = auto : 93.34 %
# k = 13 | m = minkowski | w = uniform | a = ball_tree : 93.33 %
# k = 13 | m = minkowski | w = uniform | a = kd_tree : 93.32 %
# k = 13 | m = minkowski | w = uniform | a = brute : 93.32 %
# k = 13 | m = minkowski | w = distance | a = auto : 93.31 %
# k = 13 | m = minkowski | w = distance | a = ball_tree : 93.31 %
# k = 13 | m = minkowski | w = distance | a = kd_tree : 93.31 %
# k = 13 | m = minkowski | w = distance | a = brute : 93.3 %
# k = 13 | m = euclidean | w = uniform | a = auto : 93.29 %
# k = 13 | m = euclidean | w = uniform | a = ball_tree : 93.29 %
# k = 13 | m = euclidean | w = uniform | a = kd_tree : 93.28 %
# k = 13 | m = euclidean | w = uniform | a = brute : 93.28 %
# k = 13 | m = euclidean | w = distance | a = auto : 93.27 %
# k = 13 | m = euclidean | w = distance | a = ball_tree : 93.26 %
# k = 13 | m = euclidean | w = distance | a = kd_tree : 93.25 %
# k = 13 | m = euclidean | w = distance | a = brute : 93.25 %
# k = 13 | m = manhattan | w = uniform | a = auto : 93.25 %
# k = 13 | m = manhattan | w = uniform | a = ball_tree : 93.25 %
# k = 13 | m = manhattan | w = uniform | a = kd_tree : 93.25 %
# k = 13 | m = manhattan | w = uniform | a = brute : 93.25 %
# k = 13 | m = manhattan | w = distance | a = auto : 93.25 %
# k = 13 | m = manhattan | w = distance | a = ball_tree : 93.24 %
# k = 13 | m = manhattan | w = distance | a = kd_tree : 93.24 %
# k = 13 | m = manhattan | w = distance | a = brute : 93.24 %
# k = 15 | m = minkowski | w = uniform | a = auto : 93.24 %
# k = 15 | m = minkowski | w = uniform | a = ball_tree : 93.24 %
# k = 15 | m = minkowski | w = uniform | a = kd_tree : 93.24 %
# k = 15 | m = minkowski | w = uniform | a = brute : 93.23 %
# k = 15 | m = minkowski | w = distance | a = auto : 93.22 %
# k = 15 | m = minkowski | w = distance | a = ball_tree : 93.21 %
# k = 15 | m = minkowski | w = distance | a = kd_tree : 93.21 %
# k = 15 | m = minkowski | w = distance | a = brute : 93.21 %
# k = 15 | m = euclidean | w = uniform | a = auto : 93.2 %
# k = 15 | m = euclidean | w = uniform | a = ball_tree : 93.2 %
# k = 15 | m = euclidean | w = uniform | a = kd_tree : 93.19 %
# k = 15 | m = euclidean | w = uniform | a = brute : 93.19 %
# k = 15 | m = euclidean | w = distance | a = auto : 93.19 %
# k = 15 | m = euclidean | w = distance | a = ball_tree : 93.18 %
# k = 15 | m = euclidean | w = distance | a = kd_tree : 93.18 %
# k = 15 | m = euclidean | w = distance | a = brute : 93.18 %
# k = 15 | m = manhattan | w = uniform | a = auto : 93.18 %
# k = 15 | m = manhattan | w = uniform | a = ball_tree : 93.17 %
# k = 15 | m = manhattan | w = uniform | a = kd_tree : 93.17 %
# k = 15 | m = manhattan | w = uniform | a = brute : 93.17 %
# k = 15 | m = manhattan | w = distance | a = auto : 93.17 %
# k = 15 | m = manhattan | w = distance | a = ball_tree : 93.16 %
# k = 15 | m = manhattan | w = distance | a = kd_tree : 93.16 %
# k = 15 | m = manhattan | w = distance | a = brute : 93.16 %
# k = 17 | m = minkowski | w = uniform | a = auto : 93.16 %
# k = 17 | m = minkowski | w = uniform | a = ball_tree : 93.15 %
# k = 17 | m = minkowski | w = uniform | a = kd_tree : 93.14 %
# k = 17 | m = minkowski | w = uniform | a = brute : 93.14 %
# k = 17 | m = minkowski | w = distance | a = auto : 93.13 %
# k = 17 | m = minkowski | w = distance | a = ball_tree : 93.13 %
# k = 17 | m = minkowski | w = distance | a = kd_tree : 93.12 %
# k = 17 | m = minkowski | w = distance | a = brute : 93.12 %
# k = 17 | m = euclidean | w = uniform | a = auto : 93.12 %
# k = 17 | m = euclidean | w = uniform | a = ball_tree : 93.12 %
# k = 17 | m = euclidean | w = uniform | a = kd_tree : 93.11 %
# k = 17 | m = euclidean | w = uniform | a = brute : 93.11 %
# k = 17 | m = euclidean | w = distance | a = auto : 93.1 %
# k = 17 | m = euclidean | w = distance | a = ball_tree : 93.09 %
# k = 17 | m = euclidean | w = distance | a = kd_tree : 93.09 %
# k = 17 | m = euclidean | w = distance | a = brute : 93.09 %
# k = 17 | m = manhattan | w = uniform | a = auto : 93.08 %
# k = 17 | m = manhattan | w = uniform | a = ball_tree : 93.08 %
# k = 17 | m = manhattan | w = uniform | a = kd_tree : 93.08 %
# k = 17 | m = manhattan | w = uniform | a = brute : 93.07 %
# k = 17 | m = manhattan | w = distance | a = auto : 93.07 %
# k = 17 | m = manhattan | w = distance | a = ball_tree : 93.07 %
# k = 17 | m = manhattan | w = distance | a = kd_tree : 93.07 %
# k = 17 | m = manhattan | w = distance | a = brute : 93.07 %

# %% [markdown]
# As we can see, even with so many changes, the average recall score can entirely vary in a margin of less than 1%.

# %% [markdown]
# Using the configuration that got us the best results(k = 1 | m = minkowski | w = uniform | a = auto), we can analyse its other scores.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score 
from sklearn.metrics import precision_score 
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score

accuracy_score_list = []
precision_score_list = []
recall_score_list = []
f1_score_list = [] 
print("Avg Recall Score:")
for i in range(1, 100):  
    dataset = pd.read_csv("../data/Cancer_Data.csv")
    if 'Unnamed: 32' in dataset.columns:
        dataset.drop('Unnamed: 32', axis=1, inplace=True)
    dataset['diagnosis'].replace(['B', 'M'],[0, 1], inplace=True) # B = 0, M = 1 
    x = dataset.iloc[:, 22:32]
    y = dataset['diagnosis']
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
    sc_x = StandardScaler()
    x_train = sc_x.fit_transform(x_train)
    x_test = sc_x.transform(x_test)
    classifier = KNeighborsClassifier(n_neighbors=1, metric='minkowski', weights='uniform', algorithm='auto')
    classifier.fit(x_train, y_train)
    y_pred = classifier.predict(x_test)
    accuracy_score_list.append(accuracy_score(y_test, y_pred))
    precision_score_list.append(precision_score(y_test, y_pred))
    recall_score_list.append(recall_score(y_test, y_pred))
    f1_score_list.append(f1_score(y_test, y_pred))

print("Avg Accuracy Score: ", round(100 * (sum(accuracy_score_list) / len(accuracy_score_list)), 2), "%")
print("Avg Precision Score:", round(100 * (sum(precision_score_list) / len(precision_score_list)), 2), "%")
print("Avg Recall Score:   ", round(100 * (sum(recall_score_list) / len(recall_score_list)), 2), "%")
print("Avg F1 Score:       ", round(100 * (sum(f1_score_list) / len(f1_score_list)), 2), "%")
# Out:
# Avg Recall Score:
# Avg Accuracy Score:  95.9 %
# Avg Precision Score: 94.81 %
# Avg Recall Score:    94.13 %
# Avg F1 Score:        94.4 %
